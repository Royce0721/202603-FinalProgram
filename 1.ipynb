# %%
from werkzeug.security import generate_password_hash

print(generate_password_hash("123456"))
# Out:
# scrypt:32768:8:1$9psNA9PAIbt0SXkH$d33d1dea5a86f9e2e4c047044871360e5846dd17b6a7c0aa01633a124552958f3ccc59dfe2541c52ed5b3f6c0e15ed833cad4aa6eb2dc39814414f7210dd8746
